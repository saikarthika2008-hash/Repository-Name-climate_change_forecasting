# %%
import pandas as pd
# First of all we should import pandas as pd in order to do further process
df = pd.read_csv("owid-co2-data.csv")   # For reading the uploaded dataset, we should use pd.read_csv() function
df  # It is basically used to display the csv file that we already uploaded so that we can ensure that the file has been succesfully read
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1750      AFG   2802560.0           NaN    0.000000
# 1      Afghanistan  1751      AFG         NaN           NaN    0.000000
# 2      Afghanistan  1752      AFG         NaN           NaN    0.000000
# 3      Afghanistan  1753      AFG         NaN           NaN    0.000000
# 4      Afghanistan  1754      AFG         NaN           NaN    0.000000
# ...            ...   ...      ...         ...           ...         ...
# 50406     Zimbabwe  2020      ZWE  15526887.0  2.317871e+10    0.495991
# 50407     Zimbabwe  2021      ZWE  15797220.0  2.514009e+10    0.542490
# 50408     Zimbabwe  2022      ZWE  16069061.0  2.590159e+10    0.387493
# 50409     Zimbabwe  2023      ZWE  16340829.0           NaN    0.387493
# 50410     Zimbabwe  2024      ZWE  16634366.0           NaN    0.387493
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %% [markdown]
# Here from the dataset we can understand the following points:
# 1. The data given is from 1750 till 2024, but we will be using the data from around 1980's or 1990's because from that time period the changes are considerable percentages
# 2. Country column represents the name of the contry that the data belongs
# 3. iso_code is the code of the country
# 4. gdp is Gross Domestic Product it can be calculated as gdp=C+I+G+NX, where C is Consumption, I is Investment, G is Government Spending, NX is Net Exports
# 5. co2: Total annual carbon dioxide (CO₂) emissions from fossil fuels and industry, measured in million tonnes.
# 6. co2_per_capita: Average carbon dioxide emissions per person, calculated by dividing total CO₂ by the population.
# 7. methane: Total annual methane (CH₄) emissions, measured in million tonnes of carbon dioxide equivalents (CO₂e).
# 8. nitrous_oxide: Total annual nitrous oxide (N₂O) emissions, measured in million tonnes of carbon dioxide equivalents (CO₂e).
# 9. total_ghg: Total annual greenhouse gas emissions, including CO₂, CH₄, N₂O, and fluorinated gases, measured in million tonnes of carbon dioxide equivalents (CO₂e).

# %%
df.head(10)   # head() is a function basically used to display the first few rows of the dataset 
            # We can display the required number of rows of the dataset by placing the number required in the brackets Ex:df.head(12)
# Out:
#        country  year iso_code  population  gdp  cement_co2  \
# 0  Afghanistan  1750      AFG   2802560.0  NaN         0.0
# 1  Afghanistan  1751      AFG         NaN  NaN         0.0
# 2  Afghanistan  1752      AFG         NaN  NaN         0.0
# 3  Afghanistan  1753      AFG         NaN  NaN         0.0
# 4  Afghanistan  1754      AFG         NaN  NaN         0.0
# 5  Afghanistan  1755      AFG         NaN  NaN         0.0
# 6  Afghanistan  1756      AFG         NaN  NaN         0.0
# 7  Afghanistan  1757      AFG         NaN  NaN         0.0
# 8  Afghanistan  1758      AFG         NaN  NaN         0.0
# 9  Afghanistan  1759      AFG         NaN  NaN         0.0
#
#    cement_co2_per_capita  co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                    0.0  NaN             NaN              NaN  ...
# 1                    NaN  NaN             NaN              NaN  ...
# 2                    NaN  NaN             NaN              NaN  ...
# ...

# %%
df.tail()    # The functionality is similar to the head function but it displays the rows from the end
# Out:
#         country  year iso_code  population           gdp  cement_co2  \
# 50406  Zimbabwe  2020      ZWE  15526887.0  2.317871e+10    0.495991
# 50407  Zimbabwe  2021      ZWE  15797220.0  2.514009e+10    0.542490
# 50408  Zimbabwe  2022      ZWE  16069061.0  2.590159e+10    0.387493
# 50409  Zimbabwe  2023      ZWE  16340829.0           NaN    0.387493
# 50410  Zimbabwe  2024      ZWE  16634366.0           NaN    0.387493
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# 50406               0.031944   8.490839       -1.775956       -17.298054  ...
# 50407               0.034341  10.222778        1.731939        20.397736  ...
# 50408               0.024114  12.231845        2.009067        19.652843  ...
# 50409               0.023713  13.443295        1.211450         9.904062  ...
# 50410               0.023295  13.701154        0.257859         1.918125  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# ...

# %%
print(df.shape)   # df.shape give us the size of the datset, like it displays the number of rows and columns
                  # Should not keep the parenthesis for sape again unlike other functions because it will be treated as tuple thereafter
# Out:
# (50411, 79)

# %% [markdown]
# Based on the above displayed data the following things can be drawn
# 1. The total number of columns in the dataset are 79
# 2. The total number of rows in the dataset are 50411
# 3. Based on the outputs we can also refer to the first 10 rows and the last 5 rows from the dataset

# %%
df.isnull()     # True: The cell is empty or missing data.False: The cell has actual data in it.
# Out:
#        country   year  iso_code  population    gdp  cement_co2  \
# 0        False  False     False       False   True       False
# 1        False  False     False        True   True       False
# 2        False  False     False        True   True       False
# 3        False  False     False        True   True       False
# 4        False  False     False        True   True       False
# ...        ...    ...       ...         ...    ...         ...
# 50406    False  False     False       False  False       False
# 50407    False  False     False       False  False       False
# 50408    False  False     False       False  False       False
# 50409    False  False     False       False   True       False
# 50410    False  False     False       False   True       False
#
#        cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                      False   True            True             True  ...
# ...

# %%
df.isnull().sum()
# Out:
# country                            0
# year                               0
# iso_code                        7931
# population                      9244
# gdp                            35160
#                                ...
# temperature_change_from_n2o    12131
# total_ghg                      12261
# total_ghg_excluding_lucf       12598
# trade_co2                      45699
# trade_co2_share                45699
# Length: 79, dtype: int64

# %% [markdown]
# Basically from the above code, the output we obtain is the total number of null values across the columns
# 1. Country and Year contain zero null values
# 2. Then followed by iso_code which has 7931 null values in total
# 3. gdp contain 35160 null values
# 4. It continues ad then temperature_change_from_n2o contains a total of 12131 null values
# 5. total_dhd contains 12261 null values
# 6. total_ghg_excluding_lucf contains 12598 null values
# 7. trade_co2 contains 45699 null values
# 8. trade_co2_share contains 45699 null values

# %%
null_percent = (df.isnull().sum() / len(df)) * 100    # Here df.isnull().sum()

null_df = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": null_percent
})

null_df.sort_values("Percentage", ascending=False)    # As we are asked to find the percentage of the null values per columns
# Out:
#                                       Missing Values  Percentage
# share_global_cumulative_other_co2              48241   95.695384
# share_global_other_co2                         48241   95.695384
# other_co2_per_capita                           47752   94.725358
# cumulative_other_co2                           47157   93.545060
# other_industry_co2                             47157   93.545060
# ...                                              ...         ...
# share_of_temperature_change_from_ghg            9173   18.196425
# temperature_change_from_co2                     9173   18.196425
# iso_code                                        7931   15.732677
# year                                               0    0.000000
# country                                            0    0.000000
#
# [79 rows x 2 columns]

# %%
coverage_country = df.groupby("country").size().sort_values(ascending=False) 
 # Basically for the plotting purpose we are making an table cantaining the country that has more in size

coverage_country.head(20)   # As we had already discusses in the previous cells about the head function, here we are displaying the top 20 entities
# Out:
# country
# Afghanistan                     275
# Africa                          275
# Andorra                         275
# Antarctica                      275
# Asia                            275
# Asia (excl. China and India)    275
# Bangladesh                      275
# Barbados                        275
# Bhutan                          275
# Bolivia                         275
# Australia                       275
# Bahrain                         275
# Cambodia                        275
# Brunei                          275
# Cyprus                          275
# Cote d'Ivoire                   275
# Honduras                        275
# High-income countries           275
# Greenland                       275
# Guatemala                       275
# dtype: int64

# %%
coverage_year = df.groupby("year").size()   # Here we are making the table on the basis of year 

coverage_year.tail()
# Out:
# year
# 2020    254
# 2021    254
# 2022    254
# 2023    254
# 2024    254
# dtype: int64

# %%
NON_SOVEREIGN = [
    # Continental / regional aggregates (OWID)
    "World", "Asia", "Europe", "Africa", "North America", "South America", "Oceania",
    # Continental / regional aggregates (GCP variants)
    "Africa (GCP)", "Asia (GCP)", "Europe (GCP)",
    "North America (GCP)", "South America (GCP)", "Oceania (GCP)",
    "Central America (GCP)", "Middle East (GCP)",
    # Sub-regional exclusion variants
    "Asia (excl. China and India)",
    "Europe (excl. EU-27)", "Europe (excl. EU-28)",
    "North America (excl. USA)",
    # European Union aggregates
    "European Union (27)", "European Union (28)",
    # Income / development groupings
    "High-income countries", "Low-income countries",
    "Upper-middle-income countries", "Lower-middle-income countries",
    "Least developed countries (Jones et al.)",
    # OECD / Non-OECD groupings
    "OECD (GCP)", "OECD (Jones et al.)", "Non-OECD (GCP)",
    # International transport
    "International aviation", "International shipping",
    # Special / historical entries
    "Kuwaiti Oil Fires", "Kuwaiti Oil Fires (GCP)",
    "Ryukyu Islands (GCP)",
]

# Apply full sovereign filter & target timeline rule
df_filtered = df[df["year"] >= 1990]
df_filtered = df_filtered[~df_filtered["country"].isin(NON_SOVEREIGN)]

print(f"Dataset shape after strict sovereign cleaning: {df_filtered.shape}")
# Out:
# Dataset shape after strict sovereign cleaning: (7700, 79)

# %% [markdown]
# ### Filtering Decisions
#
# 1. Kept records from 1990 onward because the project focuses on modern emissions trends.
# 2. Removed aggregate regions such as World and Asia because the analysis targets individual sovereign countries.
# 3. This improves consistency for future country-level modelling.

# %%
import matplotlib.pyplot as plt  # Import matplotlib library for creating charts and visualizations

# Group the dataset by year and sum up CO₂ emissions across all countries
global_co2 = df.groupby("year")["co2"].sum()  

# Set the size of the chart
plt.figure(figsize=(10,5))

# Plot the global CO₂ emissions over time
plt.plot(global_co2.index, global_co2.values)

# Add a title to the chart
plt.title("Global CO₂ Emissions")

# Label the x-axis as Year
plt.xlabel("Year")

# Label the y-axis as CO₂ Emissions
plt.ylabel("CO₂ Emissions")

# Add grid lines to make the chart easier to read
plt.grid(True)

# Display the chart
plt.show()

# %% [markdown]
# Global CO₂ emissions increased steadily from 1990 onward.
# Growth accelerated during the 2000s.
# A noticeable dip occurs around 2020 due to COVID-19 disruptions.
# Emissions recover in subsequent years.

# %%
top5 = ["China", "United States", "India", "Russia", "Japan"]

# %%
plt.figure(figsize=(12,6))  # Set the size of the chart

# Loop through each country in the top 5 emitters
for country in top5:
    # Filter the dataset for the current country
    subset = df[df["country"] == country]
    # Plot that country’s CO₂ emissions over time
    plt.plot(subset["year"], subset["co2"], label=country)

# Add a title to the chart
plt.title("CO₂ Emissions of Top 5 Emitters")

# Label the x-axis as Year
plt.xlabel("Year")

# Label the y-axis as CO₂ Emissions
plt.ylabel("CO₂ Emissions")

# Show the legend so each line is labeled by country
plt.legend()

# Display the chart
plt.show()

# %% [markdown]
# China shows the most rapid growth after 2000.
# US emissions peak and gradually decline.
# India shows a consistent upward trend.
# Japan and Russia remain comparatively stable.

# %%
df["decade"] = (df["year"] // 10) * 10  # We are categorising the years as decades so that it will be easy for the plotting partgithu

# %%
ghg_decade = df.groupby("decade")[
    ["co2", "methane", "nitrous_oxide"]
].sum()

# %%
import plotly.express as px

# Create decades feature element
df_filtered['decade'] = (df_filtered['year'] // 10) * 10
df_filtered['decade'] = df_filtered['decade'].astype(str) + "s"

# Melt columns for dynamic stacked grouping
melted_ghg = df_filtered.melt(
    id_vars=['decade'], 
    value_vars=['co2', 'methane', 'nitrous_oxide'],
    var_name='GHG Component', 
    value_name='Emissions (CO2e)'
).dropna()

# Group to fetch chronological sum configurations
decade_summary = melted_ghg.groupby(['decade', 'GHG Component']).sum().reset_index()

# Generate the Stacked Bar Plot
fig_decade = px.bar(
    decade_summary, 
    x='decade', 
    y='Emissions (CO2e)', 
    color='GHG Component',
    title='Global GHG Component Composition Profile by Decade (Post-1990)',
    labels={'decade': 'Decade Horizon Group', 'Emissions (CO2e)': 'Total Megatonnes (Mt)'},
    barmode='stack'
)
fig_decade.update_layout(xaxis_title="Decade Timeline", yaxis_title="Emissions (Mt CO2e)")
fig_decade.show()

# %% [markdown]
# CO₂ remains the dominant greenhouse gas.
# Methane contributes a significant but smaller share.
# Nitrous oxide contributes the least.
# The overall volume of greenhouse gases increases across decades.
